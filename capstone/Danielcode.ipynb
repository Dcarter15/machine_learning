# %%
pip install pandas_profiling
# Out:
# Collecting pandas_profiling
#   Using cached pandas_profiling-2.9.0-py2.py3-none-any.whl (258 kB)
# Requirement already satisfied: requests>=2.23.0 in c:\users\15309\anaconda3\envs\python_data\lib\site-packages (from pandas_profiling) (2.24.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: No metadata found in c:\users\15309\anaconda3\envs\python_data\lib\site-packages
# ERROR: Could not install packages due to an EnvironmentError: [Errno 2] No such file or directory: 'c:\\users\\15309\\anaconda3\\envs\\python_data\\lib\\site-packages\\requests-2.24.0.dist-info\\METADATA'

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import pandas_profiling as pp

# %%
data = pd.read_csv('DC_Course_List_Clean_2000.csv')
gpa_data = pd.read_csv('DC_Senior_Research_Data (1).csv')
gpa_data
# Out:
#                                         ID   ENTRY_DTE   EXIT_DTE EXIT_REASON  \
# 0     5C421A06-292C-4330-B780-0013C12A4A4E   7/27/2016   5/6/2017         NaN
# 1     9B431675-BF58-4747-83FD-00171C524524   1/10/2018  5/10/2019         NaN
# 2     1809C654-7DA9-4820-8250-00236C811C6E         NaN   5/5/2006   Graduated
# 3     AAC19983-D349-48F7-92F8-0037BF9F305C   5/17/2016   5/7/2016   Graduated
# 4     AA1A2779-6A7F-43AB-8B60-0058A8B9782A  12/22/2016  6/29/2018   Graduated
# ...                                    ...         ...        ...         ...
# 4479  5B1897B9-48D3-4FB0-BDDD-FFE420A0A155    6/5/2015   5/6/2017   Graduated
# 4480  B6ECB92A-A482-4F2F-A2B2-FFE767D394C9   7/26/2013  8/26/2016   Graduated
# 4481  F51C9929-0F38-48D5-9056-FFFA27EE9A80   7/13/2015  5/11/2019   Graduated
# 4482  4D459987-5992-4CF1-A545-FFFB9D9ACD84         NaN  6/10/1995   Graduated
# 4483  4D459987-5992-4CF1-A545-FFFB9D9ACD84         NaN  6/11/1993         NaN
#
#               DEGREE_DESC                   MAJOR_MINOR_DESC  career_gpa
# 0        Bachelor of Arts              Music: Music Industry        3.96
# 1     Bachelor of Science      Teacher Education: Elementary        2.56
# 2        Bachelor of Arts                         Management        4.00
# 3        Bachelor of Arts          Interdisciplinary Studies        3.68
# 4          Master of Arts  Clinical Mental Health Counseling        4.00
# ...                   ...                                ...         ...
# 4479     Bachelor of Arts            Business Administration        3.33
# 4480  Bachelor of Science            Business Administration        3.23
# 4481  Bachelor of Science                            Biology        3.17
# 4482       Master of Arts          Marriage & Family Therapy        4.00
# 4483  Bachelor of Science              Managerial Leadership        4.00
#
# [4484 rows x 7 columns]

# %%
data
# Out:
#                                          ID GENDER YR_CDE TRM_CDE   Dept  \
# 0      CB1F4A18-7026-4301B-15D-2930BE73DCD8      M   1991      QS  C
# 1      CB1F4A18-7026-4301B-15D-2930BE73DCD8      M   1991      QS  CM
# 2      CB1F4A18-7026-4301B-15D-2930BE73DCD8      M   1991      QS  CR
# 3      CB1F4A18-7026-4301B-15D-2930BE73DCD8      M   1991      QS  GEOL
# 4      CB1F4A18-7026-4301B-15D-2930BE73DCD8      M   2000      QF  BUS
# ...                                     ...    ...    ...     ...    ...
# 29877  AA4CEC33-1ABF-4F30A-0A9D-9E79222EA9C      F   2020      FA  GS106
# 29878  AA4CEC33-1ABF-4F30A-0A9D-9E79222EA9C      F   2020      FA  MTH25
# 29879  AA4CEC33-1ABF-4F30A-0A9D-9E79222EA9C      F   2020      FA  MTH25
# 29880  AA4CEC33-1ABF-4F30A-0A9D-9E79222EA9C      F   2020      FA   ELEC
# 29881  AA4CEC33-1ABF-4F30A-0A9D-9E79222EA9C      F   2020      FA    DIV
#
#       CourseID Delivery                           CRS_TITLE ATH_TEAM_MEMBR  \
# 0          330       EU        Interpersonal Communication              N
# 1          100       EU                             Chapel              N
# 2          330       EU                  Eastern Religions              N
# 3          306       EU               Volcanoes/Earthquake              N
# 4          510       EU  Is:Management Theory And Practice              N
# ...        ...      ...                                 ...            ...
# 29877      NaN      NaN           PHYSICAL SCIENCE: GEOLOGY             N
# 29878        1      NaN   CALCULUS I: DIFFERENTIAL CALCULUS             N
# 29879        2      NaN      CALCULUS II: INTEGRAL CALCULUS             N
# 29880      NaN      NaN                           ELECTIVES             N
# 29881      NaN      NaN               DIVERSITY REQUIREMENT             N
#
#       Grade HRS_ATTEMPTED  HRS_EARNED  Unnamed: 12
# 0         A             3        3.00          NaN
# 1         P             0        0.00          NaN
# 2        A-             3        3.00          NaN
# 3         P             3        3.00          NaN
# 4         A             3        3.00          NaN
# ...     ...           ...         ...          ...
# 29877    TR          2.67        2.67          NaN
# 29878    TR          2.67        2.67          NaN
# 29879    TR          3.33        3.33          NaN
# 29880    TR         30.04       30.04          NaN
# 29881    TR             0        0.00          NaN
#
# [29882 rows x 13 columns]

# %%
student_id = data.groupby('ID')
student_id.count()
# Out:
#                                       GENDER  YR_CDE  TRM_CDE  Dept  CourseID  \
# ID
# 009E2AFE-F13E-45E0A-94FC-B778292F1F7      19      19       19    19        19
# 00F39718-F54E-4F7C-9F5F-F8D462DD1625      19      19       19    19        19
# 010EECDF-E59A-4202-9616-6E89EFD2A012      16      16       16    16        16
# 017390B2A-37F-4398B-1C0-7C0FD34C13D4       7       7        7     7         7
# 0183C66FB-3EE-47BCB-71F-86F031EE70D8      13      13       13    13        13
# ...                                      ...     ...      ...   ...       ...
# FF284553-8C17-4447-8BF2-402B0A8F0CEA      13      13       13    13        13
# FF69B1BDC-F36-48CB-9221-373B5402CCA3      13      13       13    13        13
# FF78558BB-48F-4F23-985FBD-37055B67A0      21      21       21    21        21
# FF94EE61-439B-4A7FBC-16-62F430AFD890      41      41       41    41        41
# FFE78AC8-3F9B-4010-8FCF-2C1F2DE6C106      13      13       13    13        13
#
#                                       Delivery  CRS_TITLE  ATH_TEAM_MEMBR  \
# ID
# 009E2AFE-F13E-45E0A-94FC-B778292F1F7        19         19              19
# 00F39718-F54E-4F7C-9F5F-F8D462DD1625        18         19              19
# 010EECDF-E59A-4202-9616-6E89EFD2A012        16         16              16
# 017390B2A-37F-4398B-1C0-7C0FD34C13D4         7          7               7
# 0183C66FB-3EE-47BCB-71F-86F031EE70D8        13         13              13
# ...                                        ...        ...             ...
# FF284553-8C17-4447-8BF2-402B0A8F0CEA        13         13              13
# FF69B1BDC-F36-48CB-9221-373B5402CCA3        13         13              13
# FF78558BB-48F-4F23-985FBD-37055B67A0        21         21              21
# FF94EE61-439B-4A7FBC-16-62F430AFD890        41         41              41
# FFE78AC8-3F9B-4010-8FCF-2C1F2DE6C106        13         13              13
#
#                                       Grade  HRS_ATTEMPTED  HRS_EARNED  \
# ID
# 009E2AFE-F13E-45E0A-94FC-B778292F1F7     19             19          19
# 00F39718-F54E-4F7C-9F5F-F8D462DD1625     19             19          19
# 010EECDF-E59A-4202-9616-6E89EFD2A012     16             16          16
# 017390B2A-37F-4398B-1C0-7C0FD34C13D4      7              7           7
# 0183C66FB-3EE-47BCB-71F-86F031EE70D8     13             13          13
# ...                                     ...            ...         ...
# FF284553-8C17-4447-8BF2-402B0A8F0CEA     13             13          13
# FF69B1BDC-F36-48CB-9221-373B5402CCA3     13             13          13
# FF78558BB-48F-4F23-985FBD-37055B67A0     18             21          21
# FF94EE61-439B-4A7FBC-16-62F430AFD890     41             41          41
# FFE78AC8-3F9B-4010-8FCF-2C1F2DE6C106     13             13          13
#
#                                       Unnamed: 12
# ID
# 009E2AFE-F13E-45E0A-94FC-B778292F1F7            0
# 00F39718-F54E-4F7C-9F5F-F8D462DD1625            0
# 010EECDF-E59A-4202-9616-6E89EFD2A012            0
# 017390B2A-37F-4398B-1C0-7C0FD34C13D4            0
# 0183C66FB-3EE-47BCB-71F-86F031EE70D8            0
# ...                                           ...
# FF284553-8C17-4447-8BF2-402B0A8F0CEA            0
# FF69B1BDC-F36-48CB-9221-373B5402CCA3            0
# FF78558BB-48F-4F23-985FBD-37055B67A0            0
# FF94EE61-439B-4A7FBC-16-62F430AFD890            0
# FFE78AC8-3F9B-4010-8FCF-2C1F2DE6C106            0
#
# [1043 rows x 12 columns]

# %%
complete_data = data.merge(gpa_data, on='ID')

# %%
complete_data
complete_data.to_csv(r"C:\Users\15309\OneDrive\Desktop\capstone\uoclass.csv", index=False)
complete_data['ID'].nunique()
# Out:
# 183

# %%
complete_data['ID'].count()
# Out:
# 7376

# %%
count = complete_data.groupby('ID')
count['HRS_EARNED'].count()
# Out:
# ID
# 010EECDF-E59A-4202-9616-6E89EFD2A012    16
# 029BB8A6-73CB-43EC-8F57-FC109E7DD70B    33
# 02CA250E-62AA-46EB-8713-64CC6A88857A    40
# 041636D8-F9A3-45DF-8242-90AA97FBCE38    71
# 046D0962-F7E5-41A9-9710-1C7175067E09    57
#                                         ..
# F8115960-517F-42EA-8BFD-14EB0FCCA32F    35
# F9EB0B9E-125F-4F97-90D5-2E20FF858239     8
# FB3D7AB4-40B1-4B60-9979-732F6EA14269    15
# FBC53DD3-27F4-4ABA-84D1-E14257043FB9    14
# FE179FF7-7A8B-43D1-8E73-FDEE2B76C399    12
# Name: HRS_EARNED, Length: 183, dtype: int64

# %%
df = complete_data.merge(complete_data.groupby('ID')['HRS_EARNED']
           .agg(['sum']), 
         left_on='ID', 
         right_index=True)

# %%
clean = df.loc[df['sum'] >= 124]
clean
# Out:
#                                         ID GENDER YR_CDE TRM_CDE   Dept  \
# 0     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM
# 1     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM
# 2     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CS
# 3     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  FA
# 4     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  NT
# ...                                    ...    ...    ...     ...    ...
# 7315  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
# 7316  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  ECON
# 7317  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  ECON
# 7318  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
# 7319  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
#
#      CourseID Delivery                           CRS_TITLE ATH_TEAM_MEMBR  \
# 0         100       EU                             Chapel              N
# 1         105       EU                   Service Learning              N
# 2         101       EU                   Freshman Seminar              N
# 3         121       EU                   Art Appreciation              N
# 4         115       EU        Nt Themes And Personalities              N
# ...       ...      ...                                 ...            ...
# 7315      550       OL                 Managerial Finance              N
# 7316      555       OL               Managerial Economics              N
# 7317      555       OL               Managerial Economics              N
# 7318      610       OL  Operations and Service Management              N
# 7319      610       OL  Operations and Service Management              N
#
#      Grade HRS_ATTEMPTED  HRS_EARNED  Unnamed: 12  ENTRY_DTE  EXIT_DTE  \
# 0        P             0         0.0          NaN        NaN  5/5/2006
# 1        N             0         0.0          NaN        NaN  5/5/2006
# 2       B+             1         1.0          NaN        NaN  5/5/2006
# 3        C             3         3.0          NaN        NaN  5/5/2006
# 4        B             3         3.0          NaN        NaN  5/5/2006
# ...    ...           ...         ...          ...        ...       ...
# 7315   NaN             3         0.0          NaN  8/13/2018  5/9/2020
# 7316   NaN             3         0.0          NaN  8/13/2018  5/9/2020
# 7317   NaN             3         0.0          NaN  8/13/2018  5/9/2020
# 7318   NaN             3         0.0          NaN  8/13/2018  5/9/2020
# 7319   NaN             3         0.0          NaN  8/13/2018  5/9/2020
#
#      EXIT_REASON          DEGREE_DESC         MAJOR_MINOR_DESC  career_gpa  \
# 0      Graduated     Bachelor of Arts  Business Administration        2.87
# 1      Graduated     Bachelor of Arts  Business Administration        2.87
# 2      Graduated     Bachelor of Arts  Business Administration        2.87
# 3      Graduated     Bachelor of Arts  Business Administration        2.87
# 4      Graduated     Bachelor of Arts  Business Administration        2.87
# ...          ...                  ...                      ...         ...
# 7315   Graduated  Bachelor of Science  Business Administration        3.67
# 7316   Graduated  Bachelor of Science  Business Administration        3.67
# 7317   Graduated  Bachelor of Science  Business Administration        3.67
# 7318   Graduated  Bachelor of Science  Business Administration        3.67
# 7319   Graduated  Bachelor of Science  Business Administration        3.67
#
#         sum
# 0     160.0
# 1     160.0
# 2     160.0
# 3     160.0
# 4     160.0
# ...     ...
# 7315  128.0
# 7316  128.0
# 7317  128.0
# 7318  128.0
# 7319  128.0
#
# [4335 rows x 20 columns]

# %%
#df = clean.loc[clean['EXIT_REASON'] == 'Graduated']
#df

# %%
clean['Average_CreditsperYear'] = clean['sum']/4
# Out:
# C:\Users\15309\anaconda3\envs\Python_Data\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
clean
# Out:
#                                         ID GENDER YR_CDE TRM_CDE   Dept  \
# 0     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM
# 1     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM
# 2     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CS
# 3     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  FA
# 4     A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  NT
# ...                                    ...    ...    ...     ...    ...
# 7315  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
# 7316  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  ECON
# 7317  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  ECON
# 7318  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
# 7319  6E014522-1471-4149-93DB-79A9B9AAB598      M   2020      FA  BUS
#
#      CourseID Delivery                           CRS_TITLE ATH_TEAM_MEMBR  \
# 0         100       EU                             Chapel              N
# 1         105       EU                   Service Learning              N
# 2         101       EU                   Freshman Seminar              N
# 3         121       EU                   Art Appreciation              N
# 4         115       EU        Nt Themes And Personalities              N
# ...       ...      ...                                 ...            ...
# 7315      550       OL                 Managerial Finance              N
# 7316      555       OL               Managerial Economics              N
# 7317      555       OL               Managerial Economics              N
# 7318      610       OL  Operations and Service Management              N
# 7319      610       OL  Operations and Service Management              N
#
#      Grade  ... HRS_EARNED  Unnamed: 12  ENTRY_DTE  EXIT_DTE EXIT_REASON  \
# 0        P  ...        0.0          NaN        NaN  5/5/2006   Graduated
# 1        N  ...        0.0          NaN        NaN  5/5/2006   Graduated
# 2       B+  ...        1.0          NaN        NaN  5/5/2006   Graduated
# 3        C  ...        3.0          NaN        NaN  5/5/2006   Graduated
# 4        B  ...        3.0          NaN        NaN  5/5/2006   Graduated
# ...    ...  ...        ...          ...        ...       ...         ...
# 7315   NaN  ...        0.0          NaN  8/13/2018  5/9/2020   Graduated
# 7316   NaN  ...        0.0          NaN  8/13/2018  5/9/2020   Graduated
# 7317   NaN  ...        0.0          NaN  8/13/2018  5/9/2020   Graduated
# 7318   NaN  ...        0.0          NaN  8/13/2018  5/9/2020   Graduated
# 7319   NaN  ...        0.0          NaN  8/13/2018  5/9/2020   Graduated
#
#               DEGREE_DESC         MAJOR_MINOR_DESC career_gpa    sum  \
# 0        Bachelor of Arts  Business Administration       2.87  160.0
# 1        Bachelor of Arts  Business Administration       2.87  160.0
# 2        Bachelor of Arts  Business Administration       2.87  160.0
# 3        Bachelor of Arts  Business Administration       2.87  160.0
# 4        Bachelor of Arts  Business Administration       2.87  160.0
# ...                   ...                      ...        ...    ...
# 7315  Bachelor of Science  Business Administration       3.67  128.0
# 7316  Bachelor of Science  Business Administration       3.67  128.0
# 7317  Bachelor of Science  Business Administration       3.67  128.0
# 7318  Bachelor of Science  Business Administration       3.67  128.0
# 7319  Bachelor of Science  Business Administration       3.67  128.0
#
#       Average_CreditsperYear
# 0                       40.0
# 1                       40.0
# 2                       40.0
# 3                       40.0
# 4                       40.0
# ...                      ...
# 7315                    32.0
# 7316                    32.0
# 7317                    32.0
# 7318                    32.0
# 7319                    32.0
#
# [4335 rows x 21 columns]

# %%
#course_length = len(clean['CRS_TITLE'])
#students = len(clean['ID'].unique())
#average_course = course_length/students
#average_course
#class_count = clean.groupby('ID')['CRS_TITLE'].agg(['count'])
#class_count
df = clean.merge(clean.groupby('ID')['CRS_TITLE']
           .agg(['count']), 
         left_on='ID', 
         right_index=True)

# %%
df.to_csv(r"C:\Users\15309\OneDrive\Desktop\capstone\clean.csv", index=False)

# %%
df['career_gpa'].nunique()
# Out:
# 44

# %%
df['ID'].nunique()
# Out:
# 53

# %%
df.head()
# Out:
#                                      ID GENDER YR_CDE TRM_CDE   Dept CourseID  \
# 0  A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM         100
# 1  A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CM         105
# 2  A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  CS         101
# 3  A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  FA         121
# 4  A2978426-4DDD-4238-9171-F7709D3599CA      M   2001      QF  NT         115
#
#   Delivery                     CRS_TITLE ATH_TEAM_MEMBR Grade  ...  \
# 0       EU                       Chapel              N      P  ...
# 1       EU             Service Learning              N      N  ...
# 2       EU             Freshman Seminar              N     B+  ...
# 3       EU             Art Appreciation              N      C  ...
# 4       EU  Nt Themes And Personalities              N      B  ...
#
#   Unnamed: 12  ENTRY_DTE  EXIT_DTE EXIT_REASON       DEGREE_DESC  \
# 0         NaN        NaN  5/5/2006   Graduated  Bachelor of Arts
# 1         NaN        NaN  5/5/2006   Graduated  Bachelor of Arts
# 2         NaN        NaN  5/5/2006   Graduated  Bachelor of Arts
# 3         NaN        NaN  5/5/2006   Graduated  Bachelor of Arts
# 4         NaN        NaN  5/5/2006   Graduated  Bachelor of Arts
#
#           MAJOR_MINOR_DESC career_gpa    sum  Average_CreditsperYear  count
# 0  Business Administration       2.87  160.0                    40.0     72
# 1  Business Administration       2.87  160.0                    40.0     72
# 2  Business Administration       2.87  160.0                    40.0     72
# 3  Business Administration       2.87  160.0                    40.0     72
# 4  Business Administration       2.87  160.0                    40.0     72
#
# [5 rows x 22 columns]

# %%
final_df = df.drop(columns=['ID','YR_CDE','CourseID','Unnamed: 12','ENTRY_DTE','EXIT_DTE','EXIT_REASON','DEGREE_DESC','MAJOR_MINOR_DESC', 'CRS_TITLE'])

# %%
final_df
final_df = final_df.dropna()
final_df.to_csv(r"C:\Users\15309\OneDrive\Desktop\capstone\clean.csv", index=False)
final_df
# Out:
#      GENDER TRM_CDE   Dept Delivery ATH_TEAM_MEMBR Grade HRS_ATTEMPTED  \
# 0         M      QF  CM          EU             N      P             0
# 1         M      QF  CM          EU             N      N             0
# 2         M      QF  CS          EU             N     B+             1
# 3         M      QF  FA          EU             N      C             3
# 4         M      QF  NT          EU             N      B             3
# ...     ...     ...    ...      ...            ...   ...           ...
# 7307      M      SP  CM          EU             N      P             0
# 7308      M      SP  MKTG        OL             N      A             3
# 7309      M      SP  MKTG        OL             N      A             3
# 7310      M      SP  MKTG        EU             N     A-             3
# 7311      M      SP  MKTG        EU             N     A-             3
#
#       HRS_EARNED  career_gpa    sum  Average_CreditsperYear  count
# 0            0.0        2.87  160.0                    40.0     72
# 1            0.0        2.87  160.0                    40.0     72
# 2            1.0        2.87  160.0                    40.0     72
# 3            3.0        2.87  160.0                    40.0     72
# 4            3.0        2.87  160.0                    40.0     72
# ...          ...         ...    ...                     ...    ...
# 7307         0.0        3.67  128.0                    32.0     64
# 7308         3.0        3.67  128.0                    32.0     64
# 7309         3.0        3.67  128.0                    32.0     64
# 7310         3.0        3.67  128.0                    32.0     64
# 7311         3.0        3.67  128.0                    32.0     64
#
# [4286 rows x 12 columns]

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
# label encoder categorical columns: four, five, eight
label_encoder_four = LabelEncoder()  
final_df['GENDER'] = label_encoder_four.fit_transform(final_df['GENDER'])
label_encoder_five = LabelEncoder()        
final_df['TRM_CDE'] = label_encoder_five.fit_transform(final_df['TRM_CDE'])
label_encoder_eight= LabelEncoder()        
final_df['Dept'] = label_encoder_eight.fit_transform(final_df['Dept'])
label_encoder_nine= LabelEncoder()        
final_df['Delivery'] = label_encoder_nine.fit_transform(final_df['Delivery'])
label_encoder_six= LabelEncoder()        
final_df['ATH_TEAM_MEMBR'] = label_encoder_six.fit_transform(final_df['ATH_TEAM_MEMBR'])
label_encoder_two= LabelEncoder()        
final_df['Grade'] = label_encoder_two.fit_transform(final_df['Grade'])
final_df
# Out:
#       GENDER  TRM_CDE  Dept  Delivery  ATH_TEAM_MEMBR  Grade HRS_ATTEMPTED  \
# 0          1        1    14         0               1     15             0
# 1          1        1    14         0               1     13             0
# 2          1        1    16         0               1      5             1
# 3          1        1    27         0               1      7             3
# 4          1        1    50         0               1      4             3
# ...      ...      ...   ...       ...             ...    ...           ...
# 7307       1        5    14         0               1     15             0
# 7308       1        5    46         3               1      0             3
# 7309       1        5    46         3               1      0             3
# 7310       1        5    46         0               1      2             3
# 7311       1        5    46         0               1      2             3
#
#       HRS_EARNED  career_gpa    sum  Average_CreditsperYear  count
# 0            0.0        2.87  160.0                    40.0     72
# 1            0.0        2.87  160.0                    40.0     72
# 2            1.0        2.87  160.0                    40.0     72
# 3            3.0        2.87  160.0                    40.0     72
# 4            3.0        2.87  160.0                    40.0     72
# ...          ...         ...    ...                     ...    ...
# 7307         0.0        3.67  128.0                    32.0     64
# 7308         3.0        3.67  128.0                    32.0     64
# 7309         3.0        3.67  128.0                    32.0     64
# 7310         3.0        3.67  128.0                    32.0     64
# 7311         3.0        3.67  128.0                    32.0     64
#
# [4286 rows x 12 columns]

# %%
#find and outliers
quartiles = final_df['sum'].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of occupancy is: {lowerq}")
print(f"The upper quartile of occupancy is: {upperq}")
print(f"The interquartile range of occupancy is: {iqr}")
print(f"The median of occupancy is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")

#outlier_occupancy = final_df.loc[(final_df['sum'] < 
#        lower_bound) | (final_df['sum'] > upper_bound)]
#outlier_occupancy
# Out:
# The lower quartile of occupancy is: 147.0
# The upper quartile of occupancy is: 302.0
# The interquartile range of occupancy is: 155.0
# The median of occupancy is: 198.0
# Values below -85.5 could be outliers.
# Values above 534.5 could be outliers.

# %%
fig1, ax1 = plt.subplots()
ax1.boxplot(final_df['sum'])
plt.show()
fig1, ax1 = plt.subplots()
ax1.boxplot(final_df['count'])
plt.show()
plt.scatter(final_df['count'], final_df['career_gpa'])
plt.show()
plt.scatter(final_df['sum'], final_df['career_gpa'])
plt.show()

# %%
outlier = final_df.loc[final_df['sum'] <= 300]
outlier = outlier.loc[outlier['count'] <= 90]
outlier = outlier.loc[outlier['career_gpa'] >= 2.5]
outlier
# Out:
#       GENDER  TRM_CDE  Dept  Delivery  ATH_TEAM_MEMBR  Grade HRS_ATTEMPTED  \
# 0          1        1    14         0               1     15             0
# 1          1        1    14         0               1     13             0
# 2          1        1    16         0               1      5             1
# 3          1        1    27         0               1      7             3
# 4          1        1    50         0               1      4             3
# ...      ...      ...   ...       ...             ...    ...           ...
# 7307       1        5    14         0               1     15             0
# 7308       1        5    46         3               1      0             3
# 7309       1        5    46         3               1      0             3
# 7310       1        5    46         0               1      2             3
# 7311       1        5    46         0               1      2             3
#
#       HRS_EARNED  career_gpa    sum  Average_CreditsperYear  count
# 0            0.0        2.87  160.0                    40.0     72
# 1            0.0        2.87  160.0                    40.0     72
# 2            1.0        2.87  160.0                    40.0     72
# 3            3.0        2.87  160.0                    40.0     72
# 4            3.0        2.87  160.0                    40.0     72
# ...          ...         ...    ...                     ...    ...
# 7307         0.0        3.67  128.0                    32.0     64
# 7308         3.0        3.67  128.0                    32.0     64
# 7309         3.0        3.67  128.0                    32.0     64
# 7310         3.0        3.67  128.0                    32.0     64
# 7311         3.0        3.67  128.0                    32.0     64
#
# [2595 rows x 12 columns]

# %%
#final_df = final_df.dropna(axis=0, how='any')
#final_df["HRS_ATTEMPTED"] = pd.to_numeric(final_df["HRS_ATTEMPTED"], errors='coerce')
#final_df = final_df.astype("float64")
#final_df.to_csv(r"C:\Users\15309\OneDrive\Desktop\capstone\encoded_data.csv", index=False)
outlier = outlier.dropna(axis=0, how='any')
outlier["HRS_ATTEMPTED"] = pd.to_numeric(outlier["HRS_ATTEMPTED"], errors='coerce')
outlier = outlier.astype("float64")
outlier.to_csv(r"C:\Users\15309\OneDrive\Desktop\capstone\encoded_data.csv", index=False)

# %%
#result = final_df.apply(lambda x: sum(x.isnull()), axis=0) 
X = outlier.drop(labels="career_gpa", axis=1)
#X = np.array(X)
#print(X)
    
#     define label
y = outlier["career_gpa"]
#y =  np.array(y)
#print(y)

#     data split (20% test and 80% train)
from sklearn.model_selection import train_test_split
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)
   
#     data standard scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()    
scaler.fit(X_train)
#y_scaler = scaler.fit(y_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)
#y_train_scaled = y_scaler.transform(y_train)
#y_test_scaled = y_scaler.transform(y_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
model_regressor= RandomForestRegressor(n_jobs=-1, random_state=50)
# model_regressor = SVR(kernel = "poly")
print(model_regressor)
print()

model_regressor.fit(X_train, y_train)

y_predicted = model_regressor.predict(X_test)

# R2 can take values from 0 to 1. A value of 1 indicates that the regression predictions perfectly fit the data. 
r2_score_value = r2_score(y_test, y_predicted)
print("r2 score value:")
print(r2_score_value)
print()

# small MSE suggests the model is great at prediction
mean_squared_error_result = mean_squared_error(y_test, y_predicted)
# mean_squared_error_result = np.sqrt(mean_squared_error_result)
print("mean squared error:")
print(mean_squared_error_result)
print()

# small MAE suggests the model is great at prediction
mean_absolute_error_result = mean_absolute_error(y_test, y_predicted)
print("mean absolute error:")
print(mean_absolute_error_result)
print()
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=50)
#
# r2 score value:
# 0.9357651853980283
#
# mean squared error:
# 0.008216554645332557
#
# mean absolute error:
# 0.028035003852390716

# %%
fig, ax = plt.subplots()
ax.scatter(y_predicted, y_test, edgecolors=(0, 0, 1))
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
plt.show()

# %%
predictions = {'Predictions': y_predicted,
                'Actual': y_test}
predictions_df = pd.DataFrame(predictions, columns = ['Predictions', 'Actual'])
predictions_df
# Out:
#       Predictions  Actual
# 2989       3.9200    3.92
# 6371       3.0552    3.02
# 3018       3.9200    3.92
# 7013       3.6900    3.69
# 4155       3.8700    3.87
# ...           ...     ...
# 1174       3.7300    3.73
# 483        2.9734    2.97
# 6149       3.8100    3.81
# 1384       3.6600    3.66
# 6206       3.9500    3.95
#
# [519 rows x 2 columns]

# %%
#svc = final_df.loc[final_df['sum'] <= 300]
#svc

# %%
#svc = svc.dropna(axis=0, how='any')
#svc["HRS_ATTEMPTED"] = pd.to_numeric(outlier["HRS_ATTEMPTED"], errors='coerce')
#svc = svc.astype("int64")

# %%
#svc.info()

# %%
#result = final_df.apply(lambda x: sum(x.isnull()), axis=0) 
#X = svc.drop(labels="career_gpa", axis=1)
#X = np.array(X)
#print(X)
    
#     define label
#y = svc["career_gpa"]
#y =  np.array(y)
#print(y)

#     data split (20% test and 80% train)
#from sklearn.model_selection import train_test_split
#test_size = 0.2
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)
   
#     data standard scaling
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()    
#scaler.fit(X_train)
#y_scaler = scaler.fit(y_train)
#X_train = scaler.transform(X_train)
#X_test = scaler.transform(X_test)
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)
#y_train_scaled = y_scaler.transform(y_train)
#y_test_scaled = y_scaler.transform(y_test)

# %%
#from sklearn.svm import SVC 
#model = SVC(kernel='linear')
#model.fit(X_train, y_train)

# %%
 #SVC(kernel='linear')

# %%
#print('Test Acc: %.3f' % model.score(X_test, y_test))

# %%
#from sklearn.metrics import classification_report
#predictions = model.predict(X_test)
#print(classification_report(y_test, predictions,
                            #target_names=target_names))
